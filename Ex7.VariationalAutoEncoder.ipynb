# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# ##### 7th exercise: <font color="#C70039">Work with Variational Autoencoders (Generative Model)</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Date:  10.08.2026
#
# <img src="https://miro.medium.com/max/848/1*6uuK7GpIbfTb-0chqFwXXw.png" style="float: center;" width="400">
#
# ---------------------------------
# **GENERAL NOTE 1**:
# Please make sure you are reading the entire notebook, since it contains a lot of information on your tasks (e.g. regarding the set of certain parameters or a specific computational trick), and the written mark downs as well as comments contain a lot of information on how things work together as a whole.
#
# **GENERAL NOTE 2**:
# * Please, when commenting source code, just use English language only.
# * When describing an observation please use English language, too.
# * This applies to all exercises throughout this course.
#
# ---------------------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# A Variational Autoencoder (VAE), instead of compressing its input image into a fixed code in the latent space (as the classic autoencoder does), turns the input image into the parameters of a statistical distribution: a mean and a variance.
#
# This implies / imputes that the input image has been generated by a statistical process and that the randomness of this process should be taken into accounting during encoding and decoding.
#
# The VAE then uses the mean and variance parameters to randomly sample one element of that distribution, and decodes that element back to the original input.
#
# The stochasticity of this process improves robustness and forces the latent space to encode meaningful representations everywhere: every point sampled in the latent space is decoded to a valid output.
#
#
# ---------------------------------
#
# ### <font color="FFC300">TASKS</font>:
# The tasks that you need to work on within this notebook are always indicated below as bullet points.
# If a task is more challenging and consists of several steps, this is indicated as well.
# Make sure you have worked down the task list and commented your doings.
# This should be done by using markdown.<br>
# <font color=red>Make sure you don't forget to specify your name and your matriculation number in the notebook.</font>
#
# **YOUR TASKS in this exercise are as follows**:
# 1. import the notebook to Google Colab or use your local machine.
# 2. make sure you specified your name and your matriculation number in the header below my name and date.
#     * set the date too and remove mine.
# 3. read the entire notebook carefully
#     * add comments wherever you feel it necessary for better understanding
#     * run the notebook for the first time.
#     * try to understand each single step.
# 4. Review the PyTorch implementation and simplify or optimize it where appropriate.
# 5. experiment with different hyperparameters (search for the keyword 'task')
# 6. describe the three different loss curve plots. What do they show? Is this what you expected?
# 7. the main task is to visualize the latent space, the encoder has created. If you set high dimensions for the latent dim you can use T_SNE (plot 4).
# 8. describe the latent space with respect to its structure. Is this what you expected from a VAE?
# ---------------------------------

# %% [markdown]
# ### VAEs
# This code demonstrates a VAE using the MNIST dataset.
# Just like a regular autoencoder a VAE returns an array (image) of same dimensions as the input but variation can be introduced by tweaking the so-called latent vector.

# %%
# Google Colab setup: make repository files available under the expected relative paths.
import os
import subprocess
import sys

if "google.colab" in sys.modules:
    repository = "/content/AML"
    if not os.path.isdir(repository):
        subprocess.run(["git", "clone", "--depth", "1", "https://github.com/gheisenberg/AML.git", repository], check=True)
    os.chdir(repository)

# %%
# A VAE needs PyTorch for learning, torchvision for MNIST, and matplotlib for inspection.
# The device is chosen once and then used by all tensors and models.
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import v2

torch.manual_seed(1)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# %% [markdown]
# ### Model: "Encoder"
# Create an encoder model with the following properties:

# %%
# The encoder predicts a mean and log variance for each image.
# These parameters describe a Gaussian distribution in latent space.
class Encoder(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.shared_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(784, 2_000),
            nn.ReLU(),
            nn.Linear(2_000, 256),
            nn.ReLU(),
        )
        self.mean_layer = nn.Linear(256, latent_dim)
        self.log_variance_layer = nn.Linear(256, latent_dim)

    def forward(self, inputs):
        hidden = self.shared_layers(inputs)
        return self.mean_layer(hidden), self.log_variance_layer(hidden)

# %% [markdown]
# ### Model: "decoder"
# Create a decoder model with the following properties:

# %%
# The decoder maps one latent vector back to a 28 × 28 image.
# Sigmoid ensures reconstructed pixels stay in the [0, 1] MNIST range.
class Decoder(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(latent_dim, 256),
            nn.ReLU(),
            nn.Linear(256, 2_000),
            nn.ReLU(),
            nn.Linear(2_000, 784),
            nn.Sigmoid(),
        )

    def forward(self, latent_vectors):
        return self.layers(latent_vectors).view(-1, 1, 28, 28)

# %%
# Sample latent vectors with the reparameterization trick.
# Separating noise from learned parameters keeps this operation differentiable.
def sample_latent_vectors(mean, log_variance):
    # Reparameterization trick: z = mean + epsilon * standard_deviation.
    standard_deviation = torch.exp(0.5 * log_variance)
    epsilon = torch.randn_like(standard_deviation)
    return mean + epsilon * standard_deviation

# %%
# The VAE connects encoder, sampling, and decoder in one trainable module.
# Its forward method returns every value needed to compute the loss.
class VAE(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()
        self.latent_dim = latent_dim
        self.encoder = Encoder(latent_dim)
        self.decoder = Decoder(latent_dim)

    def encode(self, inputs):
        return self.encoder(inputs)

    def decode(self, latent_vectors):
        return self.decoder(latent_vectors)

    def forward(self, inputs):
        mean, log_variance = self.encode(inputs)
        latent_vectors = sample_latent_vectors(mean, log_variance)
        reconstructions = self.decode(latent_vectors)
        return reconstructions, mean, log_variance

# %%
# Reconstruction loss measures image quality; KL loss regularizes latent space.
# Both terms are needed for a useful generative model.
def vae_loss(reconstructions, inputs, mean, log_variance):
    # Sum pixel-wise BCE per image, then average over the batch.
    reconstruction_loss = F.binary_cross_entropy(reconstructions, inputs, reduction="sum") / inputs.size(0)
    kl_loss = -0.5 * torch.sum(1 + log_variance - mean.square() - log_variance.exp()) / inputs.size(0)
    total_loss = reconstruction_loss + kl_loss
    return total_loss, reconstruction_loss, kl_loss

# %%
# Start with two latent dimensions because they can be visualized directly.
# Students can increase this value and compare the resulting representations.
# Experiment with latent_dim and the optimizer settings.
latent_dim = 2
autoencoder = VAE(latent_dim=latent_dim).to(device)
optimizer = torch.optim.NAdam(autoencoder.parameters(), lr=1e-3)
print(autoencoder)

# %%
# DataLoader creates shuffled mini-batches for efficient gradient updates.
# Do not flip digit images because a flip can change their meaning.
# Horizontal flipping is intentionally omitted because it changes digit semantics.
transform = v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])
training_data = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
test_data = datasets.MNIST(root="./data", train=False, download=True, transform=transform)

training_loader = DataLoader(training_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=256, shuffle=False)

# %% [markdown]
# ### Train the model
# Train the model on the images from the training set until the losses converge.
# "history = model.fit" allows for storing the training and validation losses in a dictionary so they can be visualized later.

# %%
# Store the total, reconstruction, and KL losses after every epoch.
# Separate curves help diagnose whether one loss term dominates training.
history = {"total_loss": [], "reconstruction_loss": [], "kl_loss": []}
epochs = 30

for epoch in range(epochs):
    autoencoder.train()
    totals = {key: 0.0 for key in history}

    for images, _ in training_loader:
        images = images.to(device)
        optimizer.zero_grad()
        reconstructions, mean, log_variance = autoencoder(images)
        total_loss, reconstruction_loss, kl_loss = vae_loss(
            reconstructions, images, mean, log_variance
        )
        total_loss.backward()
        optimizer.step()

        batch_size = images.size(0)
        totals["total_loss"] += total_loss.item() * batch_size
        totals["reconstruction_loss"] += reconstruction_loss.item() * batch_size
        totals["kl_loss"] += kl_loss.item() * batch_size

    for key in history:
        history[key].append(totals[key] / len(training_data))
    print(
        f"Epoch {epoch + 1:02d}: total={history['total_loss'][-1]:.3f}, "
        f"reconstruction={history['reconstruction_loss'][-1]:.3f}, "
        f"KL={history['kl_loss'][-1]:.3f}"
    )

# %% [markdown]
# ### Visualize the results (plot 1)
# Create plots that show the losses and metrics, the reconstruction quality of
# the trained network, and the generative quality of the network.

# %%
# Plot each loss component separately instead of looking only at total loss.
# Their trends explain how the VAE balances reconstruction and regularization.
figure, axes = plt.subplots(1, 3, figsize=(18, 5))

axes[0].plot(history["total_loss"], label="total loss")
axes[0].set_ylabel("loss")
axes[0].set_xlabel("epoch")
axes[0].legend()

axes[1].plot(history["reconstruction_loss"], label="reconstruction loss")
axes[1].set_ylabel("binary cross-entropy")
axes[1].set_xlabel("epoch")
axes[1].legend()

axes[2].plot(history["kl_loss"], label="KL divergence")
axes[2].set_ylabel("KL loss")
axes[2].set_xlabel("epoch")
axes[2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Prediction of test data (plot 2)

# %%
# Compare original test digits with their reconstructions.
# Visible differences reveal information lost by the bottleneck.
autoencoder.eval()
test_images, _ = next(iter(test_loader))
with torch.inference_mode():
    reconstructions, _, _ = autoencoder(test_images.to(device))
reconstructions = reconstructions.cpu()

figure, axes = plt.subplots(2, 7, figsize=(15, 4))
for index in range(7):
    axes[0, index].imshow(test_images[index, 0], cmap="gray")
    axes[1, index].imshow(reconstructions[index, 0], cmap="gray")
    axes[0, index].axis("off")
    axes[1, index].axis("off")
plt.show()

# %% [markdown]
# ### Testing the generative quality of the network (plot 3)

# %%
# Decode a grid of latent positions to inspect the organization of latent space.
# Neighbouring positions should produce visually related digits.
if latent_dim != 2:
    raise ValueError("The two-dimensional generation grid requires latent_dim=2.")

x_axis = np.linspace(-2, 2, 10)
y_axis = np.linspace(-2, 2, 10)
canvas = np.zeros((28 * 10, 28 * 10))

autoencoder.eval()
with torch.inference_mode():
    for row, y_value in enumerate(y_axis):
        for column, x_value in enumerate(x_axis):
            latent = torch.tensor([[x_value, y_value]], dtype=torch.float32, device=device)
            generated_image = autoencoder.decode(latent)[0, 0].cpu().numpy()
            canvas[row * 28:(row + 1) * 28, column * 28:(column + 1) * 28] = generated_image

plt.figure(figsize=(12, 12))
plt.imshow(canvas, cmap="gray", extent=[-2, 2, -2, 2])
plt.xlabel("latent dimension 1")
plt.ylabel("latent dimension 2")
plt.show()

# %% [markdown]
# ### Task: Visualize the latent space (if latent_dim > 2 then by using T_SNE) (plot 4)
# #### Describe the latent space with respect to its structure.
#
# Remember: t-SNE is stochastic and therefore the results may appear slightly different every time it is re-run. So don't worry.

# %%
# Use encoder means as deterministic latent representations for plotting.
# t-SNE is used only when the latent space has more than two dimensions.
latent_means = []
labels = []
autoencoder.eval()
with torch.inference_mode():
    for images, batch_labels in test_loader:
        mean, _ = autoencoder.encode(images.to(device))
        latent_means.append(mean.cpu())
        labels.append(batch_labels)

latent_means = torch.cat(latent_means).numpy()
labels = torch.cat(labels).numpy()

if latent_dim == 2:
    embedding = latent_means
else:
    from sklearn.manifold import TSNE

    # Limit the sample for a responsive classroom demonstration.
    sample_size = min(3_000, len(latent_means))
    embedding = TSNE(
        n_components=2,
        init="pca",
        learning_rate="auto",
        random_state=1,
    ).fit_transform(latent_means[:sample_size])
    labels = labels[:sample_size]

plt.figure(figsize=(9, 7))
scatter = plt.scatter(embedding[:, 0], embedding[:, 1], c=labels, cmap="tab10", s=5, alpha=0.7)
plt.colorbar(scatter, ticks=range(10), label="digit")
plt.xlabel("latent dimension 1")
plt.ylabel("latent dimension 2")
plt.title("MNIST latent-space representation")
plt.show()
