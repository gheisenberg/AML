# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# # 11th exercise: <font color="#C70039">Interpretable Machine Learning with LIME for Image Classification</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Date:   01.08.2026
#
# <img src="https://miro.medium.com/max/1400/1*K4HCitQxRrjcFekIsSZDSg.png" style="float: center;" width="600">
#
# ---------------------------------
# **GENERAL NOTE 1**:
# Please make sure you are reading the entire notebook, since it contains a lot of information on your tasks (e.g. regarding the set of certain parameters or a specific computational trick), and the written mark downs as well as comments contain a lot of information on how things work together as a whole.
#
# **GENERAL NOTE 2**:
# * Please, when commenting source code, just use English language only.
# * When describing an observation please use English language, too.
# * This applies to all exercises throughout this course.
#
# ---------------------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# LIME stands for Local Interpretable Model-agnostic Explanations and was developed by Ribeiro et.al. in 2016 (https://arxiv.org/abs/1602.04938).
#
# In this notebook LIME is going to be used to generate explanations for an image classification task.
# The basic idea applying LIME is to understand why a deep neural network predicts that an instance (image) belongs to a certain class (labrador in this case).
# This notebook is based on previous work by Cristian Arteaga, [arteagac.github.io](https://arteagac.github.io)
#
# ---------------------------------
#
# ### <font color="FFC300">TASKS</font>:
# The tasks that you need to work on within this notebook are always indicated below as bullet points.
# If a task is more challenging and consists of several steps, this is indicated as well.
# Make sure you have worked down the task list and commented your doings.
# This should be done by using markdown.<br>
# <font color=red>Make sure you don't forget to specify your name and your matriculation number in the notebook.</font>
#
# **YOUR TASKS in this exercise are as follows**:
# 1. import the notebook to Google Colab or use your local machine.
# 2. make sure you specified your name and your matriculation number in the header below my name and date.
#     * set the date too and remove mine.
# 3. read the entire notebook carefully
#     * add comments wherever you feel it necessary for better understanding
#     * run the notebook for the first time.
# 4. test your own images to obtain explanations for your classification tasks.
# 5. change some hyperparameters
# 6. describe your observations and the LIME performance
# ---------------------------------

# %% [markdown]
# ### Imports
# Import all necessary python utilities for manipulation of images, plotting and numerical analysis.

# %%
# Google Colab setup: make repository files available under the expected relative paths.
import os
import subprocess
import sys

if "google.colab" in sys.modules:
    repository = "/content/AML"
    if not os.path.isdir(repository):
        subprocess.run(["git", "clone", "--depth", "1", "https://github.com/gheisenberg/AML.git", repository], check=True)
    os.chdir(repository)
    subprocess.run([sys.executable, "-m", "pip", "install", "--quiet", "scikit-image"], check=True)

# %%
# LIME combines superpixel perturbations, model predictions, and a local linear model.
# The seeded generator makes the random perturbations reproducible.
from copy import deepcopy
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import skimage.io
import skimage.segmentation
import skimage.transform
import torch
from PIL import Image
from sklearn.linear_model import LinearRegression
from sklearn.metrics import pairwise_distances
from torchvision.models import Inception_V3_Weights, inception_v3

rng = np.random.default_rng(666)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       4 import matplotlib.pyplot as plt
#       5 import numpy as np
# ----> 6 import skimage.io
#       7 import skimage.segmentation
#       8 import skimage.transform
#
# ModuleNotFoundError: No module named 'skimage'

# %% [markdown]
# ### Inception V3 initialization
# We use the pretrained Inception V3 model and preprocessing supplied by torchvision.

# %%
# Load pretrained Inception V3 with its matching preprocessing and class labels.
# Batch predictions to avoid one costly model call per perturbed image.
weights = Inception_V3_Weights.DEFAULT
inception_v3_model = inception_v3(weights=weights).to(device).eval()
preprocess = weights.transforms()
class_names = weights.meta["categories"]


def predict_images(images, batch_size=32):
    tensors = [preprocess(Image.fromarray(np.uint8(np.clip(image, 0, 1) * 255))) for image in images]
    probabilities = []
    for start in range(0, len(tensors), batch_size):
        batch = torch.stack(tensors[start:start + batch_size]).to(device)
        with torch.inference_mode():
            probabilities.append(torch.softmax(inception_v3_model(batch), dim=1).cpu())
    return torch.cat(probabilities).numpy()

# %% [markdown]
# ### Read and preprocess the image
# The image to be explained is resized to 299 × 299 pixels. `Xi` remains in the display-friendly `[0, 1]` range; the model-specific normalization is applied inside `predict_images`.

# %%
# Keep the image in a display-friendly [0, 1] range.
# Model-specific resizing and normalization happen inside predict_images.
Xi = skimage.io.imread("./data/cat-and-dog.jpg")
if Xi.ndim == 2:
    Xi = np.repeat(Xi[..., np.newaxis], 3, axis=2)
Xi = skimage.transform.resize(Xi[..., :3], (299, 299), anti_aliasing=True)

skimage.io.imshow(Xi)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Predict the class of the input image
# The pretrained model returns probabilities for 1,000 ImageNet classes. The following cell displays the five most probable classes for the selected image.

# %%
# Sort the probability vector to find the most likely ImageNet classes.
# The top class is the one explained by the local surrogate model.
predictions_for_image = predict_images([Xi])[0]
top_pred_classes = predictions_for_image.argsort()[-5:][::-1]

for class_index in top_pred_classes:
    print(f"{class_names[class_index]}: {predictions_for_image[class_index]:.3f}")

# %% [markdown]
# The indexes of the five most probable classes are stored in `top_pred_classes`.

# %%
top_pred_classes

# %% [markdown]
# ## LIME explanations
# The following figure illustrates the basic idea behind LIME. The figure shows light and dark gray areas which are the decision boundaries for the classes for each (x1,x2) pairs in the dataset. LIME is able to provide explanations for the predictions of an individual record (blue dot). The  explanations are created by generating a new dataset of perturbations around the instance to be explained (colored markers around the blue dot). The output or class of each generated perturbation is predicted with the machine-learning model (colored markers inside and outside the decision boundaries). The importance of each perturbation is determined by measuring its distance from the original instance to be explained. These distances are converted to weights by mapping the distances to a zero-one scale using a kernel function (see color scale for the weights). All this information: the new generated dataset, its class predictions and its weights are used to fit a simpler model, such as a linear model (blue line), that can be interpreted. The attributes of the simpler model, coefficients for the case of a linear model, are then used to generate explanations.
# <img src="./images/lime_illustration.png" alt="LIME" width="600"/>
#
# A detailed explanation of each step is shown below.

# %% [markdown]
# ### Step 1: Create perturbations of image
# For the case of image explanations, perturbations will be generated by turning on and off some of the superpixels in the image.

# %% [markdown]
# #### Extract super-pixels from image
# Superpixels are generated using the quickshift segmentation algorithm. It can be noted that for the given image, 69 superpixels were generated. The generated superpixels are shown in the image below.

# %%
# Superpixels group nearby pixels into regions that can be switched on or off together.
# LIME explains these regions instead of individual pixels.
superpixels = skimage.segmentation.quickshift(Xi, kernel_size=4, max_dist=200, ratio=0.2)
num_superpixels = np.unique(superpixels).size
num_superpixels

# %%
# Inspect the segmentation before generating perturbations.
# Adjust the quickshift settings if regions are too coarse or fragmented.
skimage.io.imshow(skimage.segmentation.mark_boundaries(Xi, superpixels))
plt.axis("off")
plt.show()

# %% [markdown]
# #### Create random perturbations
# In this example, 150 perturbations were used. However, for real life applications, a larger number of perturbations will produce more reliable explanations. Random zeros and ones are generated and shaped as a matrix with perturbations as rows and superpixels as columns. An example of a perturbation (the first one) is show below. Here, `1` represents that a superpixel is on and `0` represents it is off. Notice that the length of the shown vector corresponds to the number of superpixels in the image.

# %%
# Each binary vector keeps or hides selected superpixels.
# More perturbations can improve stability but require more model predictions.
num_perturbations = 150
perturbations = rng.binomial(1, 0.5, size=(num_perturbations, num_superpixels))
perturbations[0]

# %% [markdown]
# The following function `perturb_image` perturbs the given image (`img`) based on a perturbation vector (`perturbation`) and predefined superpixels (`segments`).

# %%
# Build a mask from active superpixel indexes and hide inactive regions.
# The result is one artificial image near the original image.
def perturb_image(image, perturbation, segments):
    active_superpixels = np.flatnonzero(perturbation)
    mask = np.isin(segments, active_superpixels)
    perturbed_image = deepcopy(image)
    perturbed_image *= mask[..., np.newaxis]
    return perturbed_image

# %% [markdown]
# Let's use the previous function to see what a perturbed image would look like:

# %%
# Display one perturbation so students can see what LIME samples.
# The next cell applies the same process to every perturbation vector.
skimage.io.imshow(perturb_image(Xi, perturbations[0], superpixels))
plt.axis("off")
plt.show()

# %% [markdown]
# ### Step 2: Predict the generated images
# This is the most computationally expensive LIME step. The perturbed images are processed in batches so that the pretrained PyTorch model can use available hardware efficiently.

# %%
# Predict all perturbed images in batches because this is the expensive LIME step.
# Every row of predictions contains probabilities for all ImageNet classes.
perturbed_images = [perturb_image(Xi, perturbation, superpixels) for perturbation in perturbations]
predictions = predict_images(perturbed_images, batch_size=32)
predictions.shape

# %% [markdown]
# ### Step 3: Compute distances between the original image and each of the perturbed images and compute weights (importance) of each perturbed image
# The distance between each randomly generated pertubation and the image being explained is computed using the cosine distance. For the shape of the `distances` array it can be noted that, as expected, there is a distance for every generated perturbation.

# %%
# Cosine distance measures the difference between a perturbation and the full image.
# Closer perturbations should receive more influence in the local model.
original_image = np.ones((1, num_superpixels))
distances = pairwise_distances(perturbations, original_image, metric="cosine").ravel()
distances.shape

# %% [markdown]
# #### Use kernel function to compute weights
# The distances are then mapped to a value between zero and one (weight) using a kernel function. An example of a kernel function with different kernel widths is shown in the plot below. Here the x axis represents distances and the y axis the weights. Depeding on how we set the kernel width, it defines how wide we want the "locality" around our instance to be. This kernel width can be set based on expected distance values. For the case of cosine distances, we expect them to be somehow stable (between 0 and 1); therefore, no fine tunning of the kernel width might be required.

# %% [markdown]
# <img src="./images/kernel.png" alt="Drawing" width="600"/>

# %%
# Convert distances into locality weights between zero and one.
# Smaller kernel widths focus the explanation more tightly around the original image.
kernel_width = 0.25
weights_for_perturbations = np.exp(-(distances ** 2) / (2 * kernel_width ** 2))
weights_for_perturbations.shape

# %% [markdown]
# ### Step 4: Use `perturbations`, `predictions` and `weights` to fit an explainable (linear) model
# A weighed linear regression model is fitted using data from the previous steps (perturbations, predictions and weights). Given that the class that we want to explain is labrador, when fitting the linear model we take from the predictions vector only the column corresponding to the top predicted class. Each coefficients in the linear model corresponds to one superpixel in the segmented image. These coefficients represent how important is each superpixel for the prediction of labrador.

# %%
# Fit a weighted linear surrogate around the selected class prediction.
# Its coefficients estimate how strongly each superpixel supports that class.
class_to_explain = top_pred_classes[0]
simpler_model = LinearRegression()
simpler_model.fit(
    X=perturbations,
    y=predictions[:, class_to_explain],
    sample_weight=weights_for_perturbations,
)
coefficients = simpler_model.coef_
coefficients

# %% [markdown]
# #### Compute top features (superpixels)
# Now, sort the coefficients to figure out which are the supperpixels, that have larger coefficients (magnitude) for the prediction of labradors. The identifiers of these top features or superpixels are shown below. Even though here the magnitude of the coefficients were used to determine the most important features, other alternatives such as forward or backward elimination can be used for feature importance selection.

# %%
# Keep the superpixels with the largest positive coefficients.
# These regions are the main visual evidence identified by the surrogate model.
num_top_features = 4
top_features = np.argsort(coefficients)[-num_top_features:]
top_features

# %% [markdown]
# #### Show LIME explanation (image with top features)
# Let's show the most important superpixels defined in the previous step in an image after covering up less relevant superpixels.

# %%
# Show only the selected regions as the final LIME explanation.
# This explains the model decision and does not prove causal image content.
mask = np.zeros(num_superpixels, dtype=bool)
mask[top_features] = True

skimage.io.imshow(perturb_image(Xi, mask, superpixels))
plt.axis("off")
plt.show()

# %% [markdown]
# This is the final step where we obtain the area of the image that produced the prediction of the class 'labrador'.
