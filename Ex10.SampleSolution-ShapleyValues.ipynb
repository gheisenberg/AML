# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# # Musterlösung / Sample solution
# ## 10th exercise: <font color="#C70039">Interpretable Machine Learning with SHAP values for image classification</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Date: 11.08.2026
#
# ---------------------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# This sample solution demonstrates SHAP for CIFAR-10 image classification. A pretrained MobileNetV3 backbone is adapted to ten classes, its classifier head is trained, and SHAP attributes predictions to image regions.

# %%
# Google Colab setup: make repository files available under the expected relative paths.
import os
import subprocess
import sys

if "google.colab" in sys.modules:
    repository = "/content/AML"
    if not os.path.isdir(repository):
        subprocess.run(["git", "clone", "--depth", "1", "https://github.com/gheisenberg/AML.git", repository], check=True)
    os.chdir(repository)
    subprocess.run([sys.executable, "-m", "pip", "install", "--quiet", "shap"], check=True)

# %%
# Combine a pretrained PyTorch vision model with SHAP image explanations.
# The sample size is deliberately small because image attributions are expensive.
import matplotlib.pyplot as plt
import numpy as np
import shap
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, models
from torchvision.transforms import v2
from torchvision.models import MobileNet_V3_Small_Weights

torch.manual_seed(1)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# %% [markdown]
# ## Load and preprocess CIFAR-10
#
# The pretrained backbone expects ImageNet normalization. Images are resized to 96 × 96 to retain a manageable SHAP computation while providing more spatial detail than the original 32 × 32 inputs.

# %%
# Apply the input normalization expected by the pretrained MobileNetV3 weights.
# CIFAR-10 images are enlarged to provide more spatial detail to the backbone.
weights = MobileNet_V3_Small_Weights.DEFAULT
normalization = v2.Normalize(
    mean=weights.transforms().mean,
    std=weights.transforms().std,
)
transform = v2.Compose(
    [v2.Resize((96, 96), antialias=True), v2.ToImage(), v2.ToDtype(torch.float32, scale=True), normalization]
)

training_data = datasets.CIFAR10(root="./data", train=True, download=True, transform=transform)
test_data = datasets.CIFAR10(root="./data", train=False, download=True, transform=transform)
training_loader = DataLoader(training_data, batch_size=128, shuffle=True, num_workers=0)
test_loader = DataLoader(test_data, batch_size=16, shuffle=False, num_workers=0)
class_names = training_data.classes

# %% [markdown]
# ## Modeling
# ### Adapt a pretrained MobileNetV3 model

# %%
# Freeze feature extraction and train only a new ten-class classifier head.
# This transfer-learning strategy needs less computation than training from scratch.
model = models.mobilenet_v3_small(weights=weights)
for parameter in model.features.parameters():
    parameter.requires_grad = False

input_features = model.classifier[-1].in_features
model.classifier[-1] = nn.Linear(input_features, 10)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.classifier.parameters(), lr=1e-3)

for epoch in range(3):
    model.train()
    running_loss = 0.0
    for images, labels in training_loader:
        images = images.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        logits = model(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * images.size(0)
    print(f"Epoch {epoch + 1}: loss={running_loss / len(training_data):.4f}")

model.eval()

# %% [markdown]
# ## Initialize the SHAP GradientExplainer

# %%
# Background images define the reference distribution for GradientExplainer.
# A small representative batch keeps the explanation step practical.
background_images, _ = next(iter(training_loader))
background_images = background_images[:20].to(device)
explainer = shap.GradientExplainer(model, background_images)

# %% [markdown]
# ## Calculate SHAP values for test images

# %%
# Explain the model's predicted class for two held-out images.
# This keeps the SHAP calculation suitable for a classroom notebook.
test_images, test_labels = next(iter(test_loader))
test_images = test_images[:2].to(device)

with torch.inference_mode():
    predicted_classes = model(test_images).argmax(dim=1).cpu().numpy()

shap_values = explainer.shap_values(test_images)

# %% [markdown]
# ## Visualize the explanations

# %%
# Support both old and current SHAP multi-output return formats.
# Convert image tensors to channel-last arrays before drawing attributions.
def select_predicted_class_attributions(values, predicted):
    # SHAP <0.45 returns one NCHW array per output; newer versions return an output axis last.
    if isinstance(values, list):
        selected = np.stack([np.asarray(values[class_index])[row] for row, class_index in enumerate(predicted)])
    else:
        values = np.asarray(values)
        selected = np.stack([values[row, ..., class_index] for row, class_index in enumerate(predicted)])
    return np.moveaxis(selected, 1, -1)


attributions = select_predicted_class_attributions(shap_values, predicted_classes)
images_for_plot = np.moveaxis(test_images.detach().cpu().numpy(), 1, -1)

# Undo normalization for a readable image background.
mean = np.asarray(weights.transforms().mean)
std = np.asarray(weights.transforms().std)
images_for_plot = np.clip(images_for_plot * std + mean, 0, 1)

for actual, predicted in zip(test_labels[:2], predicted_classes):
    print(f"Actual: {class_names[actual]} | Predicted: {class_names[predicted]}")

shap.image_plot([attributions], images_for_plot)
