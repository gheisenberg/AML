# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# # Musterlösung / Sample solution
# ## 6th exercise: <font color="#C70039">Domain Adaptation with Autoencoders</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Date:10.08.2026
#
# ---------------------------------
#
# ### Description
# This PyTorch example demonstrates image-to-image domain adaptation with a convolutional autoencoder. Try different optimizers, learning rates, and reconstruction losses and compare the results.
#
# ---------------------------------

# %%
# Google Colab setup: make repository files available under the expected relative paths.
import os
import subprocess
import sys

if "google.colab" in sys.modules:
    repository = "/content/AML"
    if not os.path.isdir(repository):
        subprocess.run(["git", "clone", "--depth", "1", "https://github.com/gheisenberg/AML.git", repository], check=True)
    os.chdir(repository)

# %%
# This image-to-image task learns a mapping from source images to target images.
# Use the selected device consistently for both model and tensors.
from pathlib import Path
import time

import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch.utils.data import DataLoader, TensorDataset
from tqdm.auto import tqdm

torch.manual_seed(1)
SIZE = 256
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# %%
# OpenCV loads BGR images, so convert them to RGB before training.
# Normalizing to [0, 1] matches the Sigmoid output layer.
def load_rgb_image(path):
    image = cv2.imread(str(path), cv2.IMREAD_COLOR)
    if image is None:
        raise FileNotFoundError(f"Could not read image: {path}")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = cv2.resize(image, (SIZE, SIZE), interpolation=cv2.INTER_AREA)
    return image.astype(np.float32) / 255.0


input_path = Path("./data/heisenberg_heisenberg/gernot")
output_path = Path("./data/heisenberg_heisenberg/walter")

# Pair the sorted source and target collections one-to-one.
input_files = sorted(path for path in input_path.iterdir() if path.is_file())
output_files = sorted(path for path in output_path.iterdir() if path.is_file())
if not input_files or len(input_files) != len(output_files):
    raise ValueError("Source and target folders must contain the same non-zero number of images.")

input_images = np.stack([load_rgb_image(path) for path in tqdm(input_files)])
output_images = np.stack([load_rgb_image(path) for path in tqdm(output_files)])

# PyTorch convolutional layers expect channels-first tensors: N x C x H x W.
input_tensor = torch.from_numpy(input_images).permute(0, 3, 1, 2)
output_tensor = torch.from_numpy(output_images).permute(0, 3, 1, 2)

test_image = load_rgb_image("./data/heisenberg_heisenberg/gernot-heisenberg-original.jpg")
test_tensor = torch.from_numpy(test_image).permute(2, 0, 1).unsqueeze(0)

start_time = time.perf_counter()

# %% [markdown]
# ## Build the convolutional encoder-decoder model

# %%
# The encoder compresses spatial features and the decoder expands them again.
# The final Sigmoid layer keeps predicted pixels within the normalized image range.
class DomainAdaptationAutoencoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 8, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(8, 8, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.decoder = nn.Sequential(
            nn.Conv2d(8, 8, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2, mode="bilinear", align_corners=False),
            nn.Conv2d(8, 8, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2, mode="bilinear", align_corners=False),
            nn.Conv2d(8, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Upsample(scale_factor=2, mode="bilinear", align_corners=False),
            nn.Conv2d(32, 3, kernel_size=3, padding=1),
            nn.Sigmoid(),
        )

    def forward(self, inputs):
        return self.decoder(self.encoder(inputs))


model = DomainAdaptationAutoencoder().to(device)
print(model)

# %%
# Each mini-batch contains matching source and target images.
# Mean squared error becomes smaller when the generated image resembles its target.
training_data = TensorDataset(input_tensor, output_tensor)
training_loader = DataLoader(training_data, batch_size=4, shuffle=True)

epochs = 50
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    for source_images, target_images in training_loader:
        source_images = source_images.to(device)
        target_images = target_images.to(device)

        optimizer.zero_grad()
        predictions = model(source_images)
        loss = criterion(predictions, target_images)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * source_images.size(0)

    epoch_loss = running_loss / len(training_data)
    print(f"Epoch {epoch + 1:03d}: loss={epoch_loss:.6f}")

elapsed = time.perf_counter() - start_time
print(f"Total computation time: {elapsed:.1f} seconds")

model_path = Path(f"domain_adapt_autoenc_epochs.{epochs}.pt")
torch.save({"model_state_dict": model.state_dict(), "size": SIZE}, model_path)

# %%
# Reload the saved weights before prediction to demonstrate model reuse.
# inference_mode avoids storing gradients because no learning happens here.
print("Output for the held-out source image")

checkpoint = torch.load(model_path, map_location=device, weights_only=True)
model.load_state_dict(checkpoint["model_state_dict"])
model.eval()

with torch.inference_mode():
    prediction = model(test_tensor.to(device)).squeeze(0).cpu()

prediction_image = prediction.permute(1, 2, 0).clamp(0, 1).numpy()
plt.imshow(prediction_image)
plt.axis("off")
plt.show()
